# %%
import pandas as pd

# %%
pd.read_csv('testdata.csv', index_col=0)
# Out:
#                          bnpp_value_log  BNPP_weight PNA_mask  PNA_wight_mask  \
# Abadik_50217497_img1           3.334655            1     None               1
# Abdisey_52768446_img1          2.451786            1     None               1
# Abenog_51901728_img1           2.647383            1     None               1
# Abeyned_51238065_img1          2.869232            1     None               1
# Abibey_51056225_img1           2.710117            1     None               1
# ...                                 ...          ...      ...             ...
# Zedusi_52495793_img1           3.447933            1     None               1
# Zigajo_52632710_img1           2.965202            1     None               1
# Zisojo_50267102_img1           1.591065            1     None               1
# Zouflible_50674523_img1        3.531862            1     None               1
# Zuliquep_52986445_img1         3.754654            1     None               1
#
# ...
